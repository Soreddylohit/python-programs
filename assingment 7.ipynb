# %%
import pandas as pd

# %%
import numpy as np

# %%
f=pd.read_csv("http://www.ldeo.columbia.edu/~rpa/usgs_earthquakes_2014.csv")

# %%
f
# Out:
#                            time   latitude   longitude    depth   mag magType  \
# 0       2014-01-31 23:53:37.000  60.252000 -152.708100   90.200  1.10      ml
# 1       2014-01-31 23:48:35.452  37.070300 -115.130900    0.000  1.33      ml
# 2       2014-01-31 23:47:24.000  64.671700 -149.252800    7.100  1.30      ml
# 3       2014-01-31 23:30:54.000  63.188700 -148.957500   96.500  0.80      ml
# 4       2014-01-31 23:30:52.210  32.616833 -115.692500   10.590  1.34      ml
# 5       2014-01-31 23:30:36.930  32.567667 -117.013500    0.010  1.51      ml
# 6       2014-01-31 23:28:04.020  33.359000 -116.360500   12.980  1.17      ml
# 7       2014-01-31 23:22:52.000  62.800200 -150.696500   86.400  1.50      ml
# 8       2014-01-31 23:20:42.000  58.169500 -151.992400   50.100  2.10      ml
# 9       2014-01-31 23:17:34.300  37.686000 -121.728700    4.200  1.60      Md
# 10      2014-01-31 23:08:03.660  -4.975800  153.946600  110.180  4.20      mb
# ...

# %%
f=pd.DataFrame(f)

# %%
f
# Out:
#                            time   latitude   longitude    depth   mag magType  \
# 0       2014-01-31 23:53:37.000  60.252000 -152.708100   90.200  1.10      ml
# 1       2014-01-31 23:48:35.452  37.070300 -115.130900    0.000  1.33      ml
# 2       2014-01-31 23:47:24.000  64.671700 -149.252800    7.100  1.30      ml
# 3       2014-01-31 23:30:54.000  63.188700 -148.957500   96.500  0.80      ml
# 4       2014-01-31 23:30:52.210  32.616833 -115.692500   10.590  1.34      ml
# 5       2014-01-31 23:30:36.930  32.567667 -117.013500    0.010  1.51      ml
# 6       2014-01-31 23:28:04.020  33.359000 -116.360500   12.980  1.17      ml
# 7       2014-01-31 23:22:52.000  62.800200 -150.696500   86.400  1.50      ml
# 8       2014-01-31 23:20:42.000  58.169500 -151.992400   50.100  2.10      ml
# 9       2014-01-31 23:17:34.300  37.686000 -121.728700    4.200  1.60      Md
# 10      2014-01-31 23:08:03.660  -4.975800  153.946600  110.180  4.20      mb
# ...

# %%
f.describe()
# Out:
#             latitude      longitude          depth            mag  \
# count  120108.000000  120108.000000  120107.000000  120065.000000
# mean       38.399579     -99.961402      28.375029       1.793958
# std        21.938258      82.996858      62.215416       1.343466
# min       -73.462000    -179.998900      -9.900000      -0.970000
# 25%        34.228917    -147.742025       4.100000       0.820000
# 50%        38.805300    -120.832000       9.200000       1.400000
# 75%        53.889500    -116.068100      22.880000       2.400000
# max        86.651400     179.998000     697.360000       8.200000
#
#                 nst           gap          dmin            rms
# count  59688.000000  94935.000000  85682.000000  119716.000000
# mean      17.878284    124.048978      0.893198       0.358174
# std       14.911369     68.518595      2.903966       0.364046
# min        0.000000      9.000000      0.000000       0.000000
# ...

# %%
#f['mag'].apply(sort_values())
f.sort_values(by='mag')
# Out:
#                            time  latitude   longitude     depth   mag magType  \
# 116943  2014-12-11 17:13:30.400   43.7200 -121.315333    1.5800 -0.97      md
# 97366   2014-10-09 21:35:19.500   43.7225 -121.315700    2.1000 -0.90      Md
# 98186   2014-10-07 07:26:23.100   43.7227 -121.313700    2.4000 -0.90      Md
# 96135   2014-10-13 12:57:26.000   43.7238 -121.316000    2.0000 -0.90      Md
# 92661   2014-10-23 21:02:22.200   43.7225 -121.313000    1.8000 -0.90      Md
# 96182   2014-10-13 09:50:54.500   43.7220 -121.313500    2.3000 -0.90      Md
# 96231   2014-10-13 06:40:26.100   43.7235 -121.313000    2.1000 -0.90      Md
# 96408   2014-10-12 21:10:18.900   43.7250 -121.314700    1.8000 -0.90      Md
# 99940   2014-10-02 03:53:12.000   43.7183 -121.314000    2.1000 -0.90      Md
# 99926   2014-10-02 05:38:45.700   43.7163 -121.316700    1.0000 -0.90      Md
# 79627   2014-09-28 09:08:29.000   43.7207 -121.315000    1.9000 -0.90      Md
# ...

# %%
f
# Out:
#                            time   latitude   longitude    depth   mag magType  \
# 0       2014-01-31 23:53:37.000  60.252000 -152.708100   90.200  1.10      ml
# 1       2014-01-31 23:48:35.452  37.070300 -115.130900    0.000  1.33      ml
# 2       2014-01-31 23:47:24.000  64.671700 -149.252800    7.100  1.30      ml
# 3       2014-01-31 23:30:54.000  63.188700 -148.957500   96.500  0.80      ml
# 4       2014-01-31 23:30:52.210  32.616833 -115.692500   10.590  1.34      ml
# 5       2014-01-31 23:30:36.930  32.567667 -117.013500    0.010  1.51      ml
# 6       2014-01-31 23:28:04.020  33.359000 -116.360500   12.980  1.17      ml
# 7       2014-01-31 23:22:52.000  62.800200 -150.696500   86.400  1.50      ml
# 8       2014-01-31 23:20:42.000  58.169500 -151.992400   50.100  2.10      ml
# 9       2014-01-31 23:17:34.300  37.686000 -121.728700    4.200  1.60      Md
# 10      2014-01-31 23:08:03.660  -4.975800  153.946600  110.180  4.20      mb
# ...

# %%
f=f.set_index('id')

# %%
l1=[]
l2=[]
for i in f["time"]:
    l1.append(i.split(" ")[0])
    l2.append(i.split(" ")[1])

# %%
f["Date"]=l1

# %%
f["Time"]=l2

# %%
f=f.drop('time',axis=1)

# %%
f
# Out:
#              latitude   longitude    depth   mag magType   nst         gap  \
# id
# ak11155107  60.252000 -152.708100   90.200  1.10      ml   NaN         NaN
# nn00436847  37.070300 -115.130900    0.000  1.33      ml   4.0  171.430000
# ak11151142  64.671700 -149.252800    7.100  1.30      ml   NaN         NaN
# ak11151135  63.188700 -148.957500   96.500  0.80      ml   NaN         NaN
# ci37171541  32.616833 -115.692500   10.590  1.34      ml   6.0  285.000000
# ci11419722  32.567667 -117.013500    0.010  1.51      ml  16.0  264.000000
# ci11419714  33.359000 -116.360500   12.980  1.17      ml  26.0  163.000000
# ak11151127  62.800200 -150.696500   86.400  1.50      ml   NaN         NaN
# ak11151125  58.169500 -151.992400   50.100  2.10      ml   NaN         NaN
# nc72153361  37.686000 -121.728700    4.200  1.60      Md   NaN  111.600000
# usc000mqlp  -4.975800  153.946600  110.180  4.20      mb   NaN   98.000000
# ...

# %%
l1=[]
l2=[]
for i in f["updated"]:
    l1.append(i.split("T")[0])
    l2.append(i.split("T")[1])

# %%
f['UpdatedDate']=l1

# %%
f['UpdatedTime']=l2

# %%
f=f.drop('updated',axis=1)

# %%
f
# Out:
#              latitude   longitude    depth   mag magType   nst         gap  \
# id
# ak11155107  60.252000 -152.708100   90.200  1.10      ml   NaN         NaN
# nn00436847  37.070300 -115.130900    0.000  1.33      ml   4.0  171.430000
# ak11151142  64.671700 -149.252800    7.100  1.30      ml   NaN         NaN
# ak11151135  63.188700 -148.957500   96.500  0.80      ml   NaN         NaN
# ci37171541  32.616833 -115.692500   10.590  1.34      ml   6.0  285.000000
# ci11419722  32.567667 -117.013500    0.010  1.51      ml  16.0  264.000000
# ci11419714  33.359000 -116.360500   12.980  1.17      ml  26.0  163.000000
# ak11151127  62.800200 -150.696500   86.400  1.50      ml   NaN         NaN
# ak11151125  58.169500 -151.992400   50.100  2.10      ml   NaN         NaN
# nc72153361  37.686000 -121.728700    4.200  1.60      Md   NaN  111.600000
# usc000mqlp  -4.975800  153.946600  110.180  4.20      mb   NaN   98.000000
# ...

# %%
f.head()
# Out:
#              latitude  longitude  depth   mag magType  nst     gap     dmin  \
# id
# ak11155107  60.252000  -152.7081  90.20  1.10      ml  NaN     NaN      NaN
# nn00436847  37.070300  -115.1309   0.00  1.33      ml  4.0  171.43  0.34200
# ak11151142  64.671700  -149.2528   7.10  1.30      ml  NaN     NaN      NaN
# ak11151135  63.188700  -148.9575  96.50  0.80      ml  NaN     NaN      NaN
# ci37171541  32.616833  -115.6925  10.59  1.34      ml  6.0  285.00  0.04321
#
#                rms net                              place        type  \
# id
# ak11155107  0.2900  ak  26km S of Redoubt Volcano, Alaska  earthquake
# nn00436847  0.0247  nn            32km S of Alamo, Nevada  earthquake
# ak11151142  1.0000  ak   12km NNW of North Nenana, Alaska  earthquake
# ak11151135  1.0700  ak         22km S of Cantwell, Alaska  earthquake
# ci37171541  0.2000  ci       10km WNW of Progreso, Mexico  earthquake
#
#                   Date          Time UpdatedDate    UpdatedTime
# id
# ...

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120108 entries, ak11155107 to ak11453389
# Data columns (total 16 columns):
# latitude       120108 non-null float64
# longitude      120108 non-null float64
# depth          120107 non-null float64
# mag            120065 non-null float64
# magType        120065 non-null object
# nst            59688 non-null float64
# gap            94935 non-null float64
# dmin           85682 non-null float64
# rms            119716 non-null float64
# net            120108 non-null object
# place          120108 non-null object
# type           120108 non-null object
# Date           120108 non-null object
# Time           120108 non-null object
# UpdatedDate    120108 non-null object
# UpdatedTime    120108 non-null object
# dtypes: float64(8), object(8)
# memory usage: 15.6+ MB

# %%
f['mag']=f['mag'].fillna(f['mag'].interpolate())

# %%
f
# Out:
#              latitude   longitude    depth   mag magType   nst         gap  \
# id
# ak11155107  60.252000 -152.708100   90.200  1.10      ml   NaN         NaN
# nn00436847  37.070300 -115.130900    0.000  1.33      ml   4.0  171.430000
# ak11151142  64.671700 -149.252800    7.100  1.30      ml   NaN         NaN
# ak11151135  63.188700 -148.957500   96.500  0.80      ml   NaN         NaN
# ci37171541  32.616833 -115.692500   10.590  1.34      ml   6.0  285.000000
# ci11419722  32.567667 -117.013500    0.010  1.51      ml  16.0  264.000000
# ci11419714  33.359000 -116.360500   12.980  1.17      ml  26.0  163.000000
# ak11151127  62.800200 -150.696500   86.400  1.50      ml   NaN         NaN
# ak11151125  58.169500 -151.992400   50.100  2.10      ml   NaN         NaN
# nc72153361  37.686000 -121.728700    4.200  1.60      Md   NaN  111.600000
# usc000mqlp  -4.975800  153.946600  110.180  4.20      mb   NaN   98.000000
# ...

# %%
f=f.sort_values(by='mag')

# %%
f
# Out:
#             latitude   longitude   depth   mag magType  nst    gap       dmin  \
# id
# uw60944536   43.7200 -121.315333    1.58 -0.97      md  3.0  190.0   0.006311
# uw60889832   43.7225 -121.315700    2.10 -0.90      Md  NaN  162.0   0.008983
# uw60920072   43.7232 -121.311800    1.90 -0.90      Md  NaN  100.8   0.008983
# uw60896022   43.7208 -121.312500    1.90 -0.90      Md  NaN   93.6   0.008983
# uw60884577   43.7238 -121.313200    1.90 -0.90      Md  NaN  169.2   0.008983
# uw60066413   46.1962 -122.171200    1.80 -0.90      Md  NaN  151.2   0.017966
# uw60895547   43.7213 -121.313700    1.80 -0.90      Md  NaN   93.6   0.008983
# uw60884892   43.7252 -121.313300    1.70 -0.90      Md  NaN  176.4   0.008983
# uw60885047   43.7242 -121.313500    2.70 -0.90      Md  NaN  172.8   0.008983
# uw60885067   43.7228 -121.313800    2.10 -0.90      Md  NaN  162.0   0.008983
# uw60885262   43.7227 -121.313200    2.20 -0.90      Md  NaN  100.8   0.008983
# ...

# %%
k=[]
k=f['mag'].tail(20)[::-1]  #reverse a column 4 sort top 20

# %%
s=[]
for i in f['place'] :   
    if ',' in i:
        s.append(i.split(",")[1])
    else:
        s.append(i)

# %%
f['state']=s

# %%
p=[]
for i in f['state']:
    p.append(i.lstrip())
#print(p)

# %%
r=[]
for i in p:
    if i in r:
        pass
    else:
        r.append(i)

# %%
from collections import Counter
g=Counter(p)
l=dict(g)

# %%
l
# Out:
# {'Oregon': 3195,
#  'Washington': 2788,
#  'Montana': 1991,
#  'Nevada': 2905,
#  'California': 44451,
#  'Wyoming': 834,
#  'Southern California': 16,
#  'Canada': 765,
#  'Utah': 1372,
#  'Alaska': 33589,
#  'Central Alaska': 101,
#  'CA': 118,
#  'Sierra Leone': 2,
#  'Off the south coast of Northwest Africa': 1,
#  'Northern California': 86,
#  'Central California': 52,
#  'northern Alaska': 166,
#  'Aleutian Islands': 210,
#  'Southern Alaska': 78,
#  'Idaho': 404,
#  'Hawaii': 2564,
#  'Puerto Rico': 2286,
#  'Tennessee': 151,
#  'Arizona': 63,
#  'offshore Northern California': 1,
#  'Missouri': 127,
#  'Mexico': 677,
#  'Southeastern Alaska': 25,
#  'western Montana': 13,
#  'southern Idaho': 5,
#  'Vermont': 1,
#  'New Jersey': 7,
#  'Alaska Peninsula': 19,
#  'New Hampshire': 10,
#  '': 355,
#  'Virginia': 6,
#  'Arkansas': 125,
#  'Colorado': 45,
#  'New York': 21,
#  '3km WSW of Quarry at CUSHENBURY': 1,
#  'Pennsylvania': 3,
#  'Kansas': 837,
# ...

# %%
h=list(l.values())

# %%
h.sort(reverse=True)

# %%
c=h[:11]

# %%
c
# Out:
# [44451, 33589, 3195, 2905, 2788, 2564, 2286, 2120, 2040, 1991, 1372]

# %%
b=[]
for i in c:
    for j in l:
        if i==l[j]:
            b.append(j)
            print(j,'-',i)
# Out:
# California - 44451
# Alaska - 33589
# Oregon - 3195
# Nevada - 2905
# Washington - 2788
# Hawaii - 2564
# Puerto Rico - 2286
# Indonesia - 2120
# Oklahoma - 2040
# Montana - 1991
# Utah - 1372

# %%
s1=f[['state','mag']].head(10)
s2=f[['state','mag']].tail(10)[::-1]
print(s1)
print(s2)
# Out:
#                   state   mag
# id
# uw60944536       Oregon -0.97
# uw60889832       Oregon -0.90
# uw60920072       Oregon -0.90
# uw60896022       Oregon -0.90
# uw60884577       Oregon -0.90
# uw60066413   Washington -0.90
# uw60895547       Oregon -0.90
# uw60884892       Oregon -0.90
# uw60885047       Oregon -0.90
# uw60885067       Oregon -0.90
#                         state  mag
# id
# usc000nzvd              Chile  8.2
# usc000rki5             Alaska  7.9
# usc000p27i              Chile  7.7
# usc000phx5    Solomon Islands  7.6
# usb000pr89   Papua New Guinea  7.5
# usc000piqj    Solomon Islands  7.4
# usb000slwn        El Salvador  7.3
# usb000pq41             Mexico  7.2
# usc000pft9   Papua New Guinea  7.1
# usc000stdc               Fiji  7.1

# %%
//anaconda/bin/pip install us
# Out:
#   File "<ipython-input-50-20fdd7faa307>", line 1
#     //anaconda/bin/pip install us
#      ^
# SyntaxError: invalid syntax

# %%
l=[2,4]
v=[]
v1=[]
u1=[]
u=[]
k=[16,32,96]
a=2
b=3
count=0
for i in range(len(l)):
    v.append(a%l[i])
    v1.append(b%l[i])
for i in range(len(k)):
    u.append(a%k[i])
    u1.append(b%k[i])
for i in range(len(u)):
    if u[i]>=a and u[i]<=b:
        count=count+1
    if u1[i]>=a and u1[i]<=b:
        count=count+1
for i in range(len(v)):
    if v[i]>=a and v[i]<=b:
        count=count+1
    if v1[i]>=a and v1[i]<=b:
        count=count+1
    
print(u,v,u1,v1)
print(count)
# Out:
# [2, 2, 2] [0, 2] [3, 3, 3] [1, 3]
# 8

# %%
if x > y:
       greater = x
   else:
       greater = y

   while(True):
       if((greater % x == 0) and (greater % y == 0)):
           lcm = greater
           break
       greater += 1

   return lcm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-cd843817fe9a> in <module>
#       1 import math
# ----> 2 math.lcm(3,4)
#
# AttributeError: module 'math' has no attribute 'lcm'
